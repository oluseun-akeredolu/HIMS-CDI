# %% [markdown]
# # HIMS–CDI Demo
#
# This notebook shows how to run the package on the synthetic dataset.

# %%
import pandas as pd
from hims_cdi import hims_cdi_eval

df=pd.read_csv("../data/synthetic_hims_cdi_dataset.csv")
print(df.head())

# %%
# Run evaluation
# !hims-cdi --data ../data/synthetic_hims_cdi_dataset.csv --output results.json

# %%
import json
res=json.load(open("results.json"))
res.keys()

# %%
# Plot CDI distribution
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv("../data/synthetic_hims_cdi_dataset.csv")
df['CDI'].hist(bins=10)
plt.xlabel("CDI score"); plt.ylabel("Count"); plt.show()
